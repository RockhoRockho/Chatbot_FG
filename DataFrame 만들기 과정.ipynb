# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'D:\DevRoot\dataset\F 카페(7,859)_new.xlsx')

# %%
cus_df = df[df['SPEAKER']=='고객']

# %%
df.columns
# Out:
# Index(['SPEAKER', 'SENTENCE', 'DOMAINID', 'DOMAIN', 'CATEGORY', 'SPEAKERID',
#        'SENTENCEID', 'MAIN', 'SUB', 'QA', 'QACNCT', 'MQ', 'SQ', 'UA', 'SA',
#        '개체명', '용어사전', '지식베이스'],
#       dtype='object')

# %%
li1 = ['메뉴추천요구', '메뉴문의', '계절메뉴주문문의', '재료문의', '빵종류문의', '제조시간문의', '신메뉴문의', '메뉴판요구', '제조방법',
'MD제품문의', '더치커피티백판매문의', '보관방법문의', '베이커리제조문의', '인기메뉴문의', '원두원산지문의', '판매여부문의']
li2 = ['일반주문', '메뉴추가주문', '메뉴추가문의', '주문가능여부문의', '기프티콘쿠폰멤버십메뉴변경문의', '단체주문문의', '주문내용변경',
'주문취소', '리필문의', '주문가능여부']

# %%
li3 = ['에스프레소샷개수문의', '특정원두요구', '원두인스턴트커피로스팅문의', '에스프레소샷개수요구', '시럽요구', '시럽', '시럽설탕요구',
    '사이즈요구', '사이즈문의', '캐리어요구', '옵션추가문의', '옵션추가요구', '조리요구', 
    '음료온도문의', '음료온도요구', '뜨거운차가운물요구', '얼음요구', '얼음량요구', '물우유량요구', '우유변경', '빨대',
    '테이크아웃요구', '테이크아웃문의', '테이크아웃용기추가금액문의', '테이크아웃용기요청']

# 필요없는 것 : '특정재료첨삭요구', '특정재료추가요구', '테이카아웃요구', '음식이주문과다른경우',
#    '서빙요구', '머그컵요구', '텀블러사용', '식기류요구', '물물컵', '냅킵물티슈요구', '휴지요구', 
#    '물티슈요구', '남은커피가루문의', '남은음료테이크아웃문의', '컵요구', '일회용포크나이프요구'

new_df = pd.concat(list(map(lambda x: cus_df[cus_df.MAIN == x], li3)))
len(new_df)
# Out:
# 635

# %%
df[df.MAIN == '계열사문의']
# Out:
#      SPEAKER                                           SENTENCE DOMAINID  \
# 3162      고객                                         여기 체인점이에요?        F
# 3163      점원                                           네 체인점입니다        F
# 3204      고객                    신세계 포인트 사용이 되어있는데 신세계랑 관련이 있어요?        F
# 3205      점원  네 저희는 신세계 계열 스타벅스라서 전국 어디서든 신세계 적립과 상품권 사용이 가능합니다        F
# 3974      고객                                           본점도 있어요?        F
# 3975      점원                                       저희 매장이 본점이에요        F
# 4042      고객                                         여기 체인점이에요?        F
# 4043      점원                                        아뇨 개인 카페입니다        F
# 4132      고객                                           체인점인가봐요?        F
# 4133      점원                                네 서울 경기 지역에 많이 있습니다        F
# 4136      고객                                   여기 매장은 국내 브랜드에요?        F
# 4137      점원                                      네 국내 브랜드 맞습니다        F
# ...

# %%
li4 = ['쿠폰멤버십적립문의', '현금영수증요청', '결제요청', '기프티콘쿠폰멤버십사용문의', '기프티콘쿠폰멤버십결제요구', '할인요청', 
'쿠폰문의', '가격문의', '텀블러할인문의', '모바일페이결제', '영수증요청','결제문의', '포인트충전', '할인문의', '현금영수증문의',
'핸드폰번호이용적립', '주차권주차도장요구', '분할결제', '카드결제(카드오류상황)', '영수증문의', '테이크아웃할인문의',
'샷토핑추가시추가금액문의', '현금영수증']

# %%
li5 = ['화장실위치문의', '와이파이문의', '콘센트자리문의', '자리여부문의', '영업시간문의', '1인1잔문의', '매장내에서일회용사용문의',
 '시설문의', '냅킨물티슈요구', '매장이용문의', '냉방조절', '물품위치문의', '주차문의', '주변시설', '단체석문의', '기타문의', '핸드폰충전요청'
'화장실비밀번호문의', '일회용컵요구', '화장실휴지비치문의', '기프티콘쿠폰멤버실결제요구', '휴일문의', '애완견출입문의', '식기류쟁반반납',
'이벤트문의', '화장실이용문의', '픽업문의', '배달문의', '영수증버리기', '단골손님임을주장', '늘먹던음료요구', '시식요청', '음식에이물질이있는경우',
'메뉴가나오는것을재촉하는상황', '계열사문의', '메뉴판문의', '체인점문의', '인터넷판매문의', '베이커리정보문의', '납품문의']

# %%
new_df[new_df.MAIN == '옵션추가요구']
# Out:
#      SPEAKER                      SENTENCE DOMAINID DOMAIN CATEGORY  \
# 214       고객            그럼 사이즈업은 얼마 추가인가요?        F     카페       카페
# 636       고객                혹시 휘핑크림 추가되나요?        F     카페       카페
# 638       고객            네 그럼 휘핑크림 추가해서 주세요        F     카페       카페
# 644       고객  갈릭 치즈 브레드에 생크림을 올려주실 수는 없나요?        F     카페       카페
# 646       고객                 네 그렇게 만들어 주세요        F     카페       카페
# 782       고객    그리고 휘핑크림은 에스프레소 크림으로 올려주세요        F     카페       카페
# 866       고객                        추가해주세요        F     카페       카페
# 1022      고객  휘핑크림에 캐러멜 드리블이랑 통 잡아 칩 깔아주세요        F     카페       카페
# 1194      고객                       네 올려주세요        F     카페       카페
# 1270      고객                   휘핑크림 추가되나요?        F     카페       카페
# 1642      고객                    그리고 휘핑해주세요        F     카페       카페
# 1750      고객                      네 추가해주세요        F     카페       카페
# 1822      고객                    휘핑 추가도 할게요        F     카페       카페
# ...

# %%
lis1 = []
for i in li1:
    lis.append(len(df[df.MAIN == i]))
lis1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_1296/4141461117.py in <module>
#       1 lis1 = []
#       2 for i in li1:
# ----> 3     lis.append(len(df[df.MAIN == i]))
#       4 lis1
#
# NameError: name 'lis' is not defined

# %%
lis2 = []
for i in li2:
    lis2.append(len(df[df.MAIN == i]))
lis2

# %%
lis3 = []
for i in li3:
    lis3.append(len(df[df.MAIN == i]))
lis3

# %%
lis4 = []
for i in li4:
    lis4.append(len(df[df.MAIN == i]))
lis4

# %%
lis5 = []
for i in li5:
    lis5.append(len(df[df.MAIN == i]))
lis5

# %%
import pandas as pd
import numpy as np
result = []
df = pd.read_csv(r'D:\DevRoot\dataset\menu.xlsx - Sheet1.csv')
for i in df['개체명']:
    result += i.split(' ')
    
result = list(map(lambda x : x.replace(',', ''), result))
result
# Out:
# ['아이스',
#  '아메리카노',
#  '하나',
#  '테이크아웃',
#  '텀블러',
#  '텀블러',
#  '할인',
#  '300원',
#  '그란데',
#  '사이즈',
#  '적립카드',
#  '쿠폰',
#  '결제',
#  '현금영수증',
#  '대기',
#  '카푸치노',
#  '주문',
#  '시럽',
#  '얼마나',
#  '3번',
#  '위',
#  '크림',
#  '이벤트',
#  '커피',
#  '주문',
#  '2000원',
#  '추가',
#  '브레드',
#  '2000원',
#  '추가',
#  '브레드',
#  '카푸치노',
#  '브레드',
#  '결제',
#  '도장',
#  '기프티콘',
#  '사용',
#  '사용',
#  '가능',
#  '키프티콘',
#  '주문',
#  '자바칩',
#  '프라푸치노',
#  '휘핑',
#  '6600원',
#  '번호',
#  '입력',
#  '아메리카노',
#  '한',
#  '잔',
#  '아이스',
#  '라떼',
#  '한',
#  '잔',
#  '중간',
#  '테이크',
#  '아웃',
#  '카운터',
#  '테이크',
#  '아웃',
#  '잔',
#  '스콘',
#  '3개',
#  '카푸치노',
#  '아이스',
#  '카푸치노',
#  '개인컵',
#  '개인컵',
#  '사이즈',
#  '음료',
#  '음료',
#  '빵',
#  '추천',
#  '호두',
#  '베이글',
#  '모바일',
#  '쿠폰',
#  '결제',
#  '화장실',
#  '오른쪽',
#  '벽',
#  '제일',
#  '커피',
#  '라이트',
#  '맛',
#  '아이스',
#  '아메리카노',
#  '가게',
#  '마스코트',
#  '메뉴',
#  '한',
#  '잔',
#  '카페라떼',
#  '쿠폰',
#  '10개',
#  '커피',
#  '한',
#  '잔',
#  '자리',
#  '아메리카노',
#  '톨',
#  '사이즈',
#  '멤버십',
#  '할인',
# ...

# %%
words = []
for word in result:
        if not word in words:
            words.append(word)
dic_df = pd.DataFrame(pd.Series(words))
dic_df2 = pd.concat([dic_df, dic_df], axis=1)
dic_df2.columns = ['이름', '형태소']
dic_df2['형태소'] = 'NNG'
dic_df2
dic_df2.to_csv('my_dict.tsv', sep='\t', index=0, header=None)

# %%
# 전처리 모듈은 챗봇 엔진 내에서 자주 사용하기 때문에 클래스로 설계 해 둡니다

from konlpy.tag import Komoran
import pickle
import jpype

class Preprocess:
    def __init__(self, userdic=None):  # 생성자 
     
        # ① 형태소 분석기 초기화
        self.komoran = Komoran(userdic=userdic)

        # ② 제외할 품사
        # 참조 : https://docs.komoran.kr/firststep/postypes.html
        # 관계언 제거, 기호 제거
        # 어미 제거
        # 접미사 제거
        self.exclusion_tags = [
            'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
            'JX', 'JC',
            'SF', 'SP', 'SS', 'SE', 'SO',
            'EP', 'EF', 'EC', 'ETN', 'ETM',
            'XSN', 'XSV', 'XSA'
        ]

    # ③ 형태소 분석기 POS 태거
    #  이렇게 래퍼(wrapper) 를 만들어 두면 나중에 형태소 분석기 종류를 바꾸어도 동작할수 있다. (유지보수 측면 good)
    def pos(self, sentence):
        return self.komoran.pos(sentence)

    # ④ 불용어 제거 후, 필요한 품사 정보만 가져오기
    def get_keywords(self, pos, without_tag=False):
        f = lambda x: x in self.exclusion_tags
        word_list = []
        for p in pos:
            if f(p[1]) is False:
                word_list.append(p if without_tag is False else p[0])
        return word_list

# %%
import pandas as pd
import numpy as np

df = pd.read_excel(r'D:\DevRoot\dataset\F 카페(7,859)_new.xlsx')
df
# Out:
#      SPEAKER              SENTENCE DOMAINID DOMAIN CATEGORY  SPEAKERID  \
# 0         고객          아이스아메리카노 하나요        F     카페       카페        1.0
# 1         점원          테이크아웃하실 건가요?        F     카페       카페        0.0
# 2         고객          네 텀블러에 넣어주세요        F     카페       카페        1.0
# 3         점원     텀블러 할인 300원 해드릴게요        F     카페       카페        0.0
# 4         고객          그란데 사이즈로 주세요        F     카페       카페        1.0
# ...      ...                   ...      ...    ...      ...        ...
# 7854      고객  아이스 아메리카노는 가격이 다른가요?        F     카페       카페        1.0
# 7855      고객       텀블러 할인하면 얼마인가요?        F     카페       카페        1.0
# 7856      고객          총 가격이 얼마입니까?        F     카페       카페        1.0
# 7857      고객     다 합쳐서 가격이 얼마인 거죠?        F     카페       카페        1.0
# 7858      고객      에스프레소 가격은 얼마입니까?        F     카페       카페        1.0
#
#      SENTENCEID   MAIN      SUB QA QACNCT                    MQ            SQ  \
# ...

# %%
p = Preprocess(userdic=r'D:\DevRoot\dataset\train_tsv')
key_li = []

# %%
for sent in df['SENTENCE']:
    key_li.append(p.get_keywords(p.pos(sent)))

# %%
key_li
# Out:
# [[('아이스', 'NNG'), ('아메리카노', 'NNG'), ('하나', 'NNG')],
#  [('테이크아웃', 'NNG'), ('걸', 'VV')],
#  [('네', 'MM'), ('텀블러', 'NNG'), ('넣', 'VV'), ('주', 'VX')],
#  [('텀블러', 'NNG'),
#   ('할인', 'NNG'),
#   ('300', 'SN'),
#   ('원', 'NNB'),
#   ('하', 'VV'),
#   ('드리', 'VX')],
#  [('그란데', 'NNG'), ('사이즈', 'NNG'), ('주', 'VX')],
#  [('적립카드', 'NNG'), ('있', 'VX')],
#  [('네', 'MM'), ('보고', 'NNG'), ('쿠폰', 'NNG'), ('결제', 'NNG')],
#  [('현금영수증', 'NNG'), ('하', 'VV'), ('드리', 'VX')],
#  [('괜찮', 'VA')],
#  [('저쪽', 'NP'), ('잠시', 'MAG'), ('대기', 'NNG'), ('주', 'VX')],
#  [('저', 'MM'), ('카푸치노', 'NNG'), ('주문', 'NNG')],
#  [('시럽', 'NNG'), ('얼마', 'NNG'), ('뿌리', 'VV'), ('드리', 'VX')],
#  [('3', 'SN'), ('번', 'NNB'), ('뿌리', 'VV'), ('주', 'VX')],
#  [('위', 'NNG'), ('크림', 'NNG'), ('올리', 'VV'), ('드리', 'VX')],
#  [('네', 'MM'), ('많이', 'MAG'), ('올리', 'VV'), ('주', 'VX')],
#  [('오늘', 'NNG'),
#   ('이벤트', 'NNG'),
#   ('하', 'VV'),
#   ('커피', 'NNG'),
#   ('주문', 'NNG'),
#   ('2000', 'SN'),
#   ('원', 'NNB'),
#   ('추가', 'NNG'),
# ...

# %%
from selenium import webdriver

# %%
driver_path = r'D:\DevRoot\dataset\bin\chromedriver.exe'
driver = webdriver.Chrome(driver_path)
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/1831011207.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)

# %%
driver.get("https://www.ediya.com/contents/drink.html?chked_val=12,13,14,15,16,71,83,&skeyword=#c")

# %%
imgs = driver.find_elements_by_css_selector('#menu_ul > li > a > img')
len(imgs)
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/1024841278.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   imgs = driver.find_elements_by_css_selector('#menu_ul > li > a > img')
# 188

# %%
drink_imgs = list(map(lambda x : x.get_attribute('src'), imgs))
drink_imgs
# Out:
# ['https://www.ediya.com/files/menu/IMG_1649840384779.png',
#  'https://www.ediya.com/files/menu/IMG_1649841665354.png',
#  'https://www.ediya.com/files/menu/IMG_1649841812108.png',
#  'https://www.ediya.com/files/menu/IMG_1649842092365.png',
#  'https://www.ediya.com/files/menu/IMG_1649842079840.png',
#  'https://www.ediya.com/files/menu/IMG_1649842193304.png',
#  'https://www.ediya.com/files/menu/IMG_1651137286136.png',
#  'https://www.ediya.com/files/menu/IMG_1651137448268.png',
#  'https://www.ediya.com/files/menu/IMG_1652751437621.png',
#  'https://www.ediya.com/files/menu/IMG_1653350749118.png',
#  'https://www.ediya.com/files/menu/IMG_1653350859774.png',
#  'https://www.ediya.com/files/menu/',
#  'https://www.ediya.com/files/menu/',
#  'https://www.ediya.com/files/menu/IMG_1648684082157.png',
#  'https://www.ediya.com/files/menu/IMG_1647319791824.png',
#  'https://www.ediya.com/files/menu/IMG_1647319802637.png',
#  'https://www.ediya.com/files/menu/IMG_1647319813487.png',
# ...

# %%
names = driver.find_elements_by_css_selector('div.menu_tt > a:nth-child(1) > span')
len(names)
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/3667932828.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   names = driver.find_elements_by_css_selector('div.menu_tt > a:nth-child(1) > span')
# 188

# %%
texts = list(map(lambda x : x.text, names))
texts
# Out:
# ['ICED 달고나 믹스치노',
#  '(EX) ICED 달고나 믹스치노',
#  'ICED 모카칩 믹스치노',
#  '(EX) ICED 모카칩 믹스치노',
#  '(EX) ICED 믹스라떼',
#  '(EX) ICED 버블믹스라떼',
#  '망고패션 요거놀라 1인빙수',
#  '딸기피치 요거놀라 1인빙수',
#  '이디야 워터',
#  '생과일 토마토주스',
#  '(EX) 생과일 토마토주스',
#  '생과일 수박주스',
#  '(EX) 생과일 수박주스',
#  'ICED 크림샷 라떼',
#  'HOT 더블 토피넛 라떼',
#  'ICED 더블 토피넛 라떼',
#  'HOT 더블 토피넛 위드샷',
#  'ICED 더블 토피넛 위드샷',
#  '토피넛 플랫치노',
#  'HOT 그린루이보스',
#  'ICED 그린루이보스',
#  'HOT 샤인히비스커스',
#  'ICED 샤인히비스커스',
#  'HOT 스프링캐모마일',
#  'ICED 스프링캐모마일',
#  'HOT 퓨어페퍼민트',
#  'ICED 퓨어페퍼민트',
#  'HOT 프레시그린티',
#  'ICED 프레시그린티',
#  'HOT 피치얼그레이',
#  'ICED 피치얼그레이',
#  '팥인절미 1인빙수',
#  '망고요거트 1인빙수',
#  '이디야 청포도&케일 주스',
#  '이디야 감귤&한라봉 주스',
#  '이디야 사과&당근 주스',
#  'ICED 복분자 뱅쇼',
#  'HOT 복분자 뱅쇼',
#  'ICED 복분자 뱅쇼 콤부차',
#  'HOT 아인슈페너',
#  'ICED 아인슈페너',
#  'HOT 쌍화차',
#  'ICED 쌍화차',
#  'HOT 생강차',
#  'ICED 생강차',
#  'ICED 달고나 라떼',
#  '(EX) ICED 달고나 라떼',
#  '이디야 콤부차 복숭아망고',
#  '이디야 콤부차 청포도레몬',
#  '(EX) ICED 디카페인 콜드브루 아메리카노',
#  'ICED 디카페인 콜드브루 아메리카노',
#  'ICED 디카페인 콜드브루 라떼',
# ...

# %%
driver.get("https://www.ediya.com/contents/bakery.html?chked_val=17,18,19,128,&skeyword=#blockcate")

# %%
cook_imgs = driver.find_elements_by_css_selector('#menu_ul > li > a > img')
cook_imgs2 = list(map(lambda x : x.get_attribute('src'), cook_imgs))
cook_imgs2
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/4030016042.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   cook_imgs = driver.find_elements_by_css_selector('#menu_ul > li > a > img')
# ['https://www.ediya.com/files/menu/IMG_1650854405321.png',
#  'https://www.ediya.com/files/menu/IMG_1650861549759.png',
#  'https://www.ediya.com/files/menu/IMG_1622445677493.png',
#  'https://www.ediya.com/files/menu/IMG_1622445874895.png',
#  'https://www.ediya.com/files/menu/IMG_1649289699539.png',
#  'https://www.ediya.com/files/menu/IMG_1594788417235.png',
#  'https://www.ediya.com/files/menu/IMG_1645420645211.png',
#  'https://www.ediya.com/files/menu/IMG_1645421037510.png',
#  'https://www.ediya.com/files/menu/IMG_1640565467814.png',
#  'https://www.ediya.com/files/menu/IMG_1640565626489.png',
#  'https://www.ediya.com/files/menu/IMG_1640565931879.png',
# ...

# %%
cook_texts = driver.find_elements_by_css_selector('#menu_ul > li span')
cook_texts2 = list(map(lambda x : x.text, cook_texts))
cook_texts2
cook_texts3 = []
for text in cook_texts2:
    if text == '':
        continue
    else:
        cook_texts3.append(text)
cook_texts3
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/2943681300.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   cook_texts = driver.find_elements_by_css_selector('#menu_ul > li span')
# ['하와이안 스퀘어 피자',
#  '불닭고구마 스퀘어 피자',
#  '이디야 단백질바(초코쿠키)',
#  '비타민바(그릭요거트)',
#  '초코프레첼 미니',
#  '꿀오란다',
#  '쌍쌍 츄로스',
#  '초콜릿 디핑',
#  '생딸기 연유 브레드',
#  '생딸기 와플',
#  '생딸기 크로플',
#  '토피넛 크로플',
#  '토피넛 꽈루아상',
#  '플레인 크로플',
#  '플레인 꽈루아상',
#  '크리미초코 감자쿠키',
#  '크리미치즈 그레인쿠키',
#  '고구마 말랭이',
#  '미니 코코 크런치',
#  '바닐라 웨이퍼스',
#  '미니프레첼 볶음양념맛',
#  '미니프레첼 와사비맛',
#  '아이스콘 초코',
#  '아이스콘 요구르트',
#  '그릴드 치킨 샐러드 & 시저 드레싱',
#  '두부텐더 콥샐러드',
#  '매콤 로제 구운주먹밥',
#  '까르보나라 구운주먹밥',
#  '양송이 수프',
#  '콘 수프',
#  '초코렛청크 쿠키',
#  '화이트초코 마카다미아 쿠키',
#  '클래식 미니 스콘',
#  '초콜릿 브라우니',
#  '아이스크림 호떡',
#  '꿀호떡',
#  '초콜릿 마카롱',
#  '산딸기 마카롱',
#  '바닐라 마카롱',
#  '이너츠',
#  '베이컨 포테이토 스퀘어 피자',
#  '허니 고르곤졸라 스퀘어 피자',
#  '햄앤치즈샌드위치',
#  '피넛버터앤딸기잼 샌드위치',
#  '팥앤크림 샌드위치',
# ...

# %%
import requests
import os
import urllib.parse as urlparser
from os.path import basename
dirname = r'D:\github\Chatbot_FG\img'

if not os.path.exists(dirname):
    os.mkdir(dirname)
    print('디렉토리', dirname, '생성')

# %%
for url in cook_imgs2:
    disassembled = urlparser.urlparse(url)
    filename = basename(disassembled.path)
    print('다운로드:', url, '->', filename)
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(os.path.join(dirname, filename), 'wb') as f:
            f.write(response.content)
# Out:
# 다운로드: https://www.ediya.com/files/menu/IMG_1650854405321.png -> IMG_1650854405321.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1650861549759.png -> IMG_1650861549759.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1622445677493.png -> IMG_1622445677493.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1622445874895.png -> IMG_1622445874895.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1649289699539.png -> IMG_1649289699539.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1594788417235.png -> IMG_1594788417235.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1645420645211.png -> IMG_1645420645211.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1645421037510.png -> IMG_1645421037510.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1640565467814.png -> IMG_1640565467814.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1640565626489.png -> IMG_1640565626489.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1640565931879.png -> IMG_1640565931879.png
# ...

# %%
for url in drink_imgs:
    disassembled = urlparser.urlparse(url)
    filename = basename(disassembled.path)
    print('다운로드:', url, '->', filename)
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(os.path.join(dirname, filename), 'wb') as f:
            f.write(response.content)
# Out:
# 다운로드: https://www.ediya.com/files/menu/IMG_1649840384779.png -> IMG_1649840384779.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1649841665354.png -> IMG_1649841665354.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1649841812108.png -> IMG_1649841812108.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1649842092365.png -> IMG_1649842092365.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1649842079840.png -> IMG_1649842079840.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1649842193304.png -> IMG_1649842193304.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1651137286136.png -> IMG_1651137286136.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1651137448268.png -> IMG_1651137448268.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1652751437621.png -> IMG_1652751437621.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1653350749118.png -> IMG_1653350749118.png
# 다운로드: https://www.ediya.com/files/menu/IMG_1653350859774.png -> IMG_1653350859774.png
# ...

# %%
menu_text = cook_texts3 + texts
menu_text
# Out:
# ['하와이안 스퀘어 피자',
#  '불닭고구마 스퀘어 피자',
#  '이디야 단백질바(초코쿠키)',
#  '비타민바(그릭요거트)',
#  '초코프레첼 미니',
#  '꿀오란다',
#  '쌍쌍 츄로스',
#  '초콜릿 디핑',
#  '생딸기 연유 브레드',
#  '생딸기 와플',
#  '생딸기 크로플',
#  '토피넛 크로플',
#  '토피넛 꽈루아상',
#  '플레인 크로플',
#  '플레인 꽈루아상',
#  '크리미초코 감자쿠키',
#  '크리미치즈 그레인쿠키',
#  '고구마 말랭이',
#  '미니 코코 크런치',
#  '바닐라 웨이퍼스',
#  '미니프레첼 볶음양념맛',
#  '미니프레첼 와사비맛',
#  '아이스콘 초코',
#  '아이스콘 요구르트',
#  '그릴드 치킨 샐러드 & 시저 드레싱',
#  '두부텐더 콥샐러드',
#  '매콤 로제 구운주먹밥',
#  '까르보나라 구운주먹밥',
#  '양송이 수프',
#  '콘 수프',
#  '초코렛청크 쿠키',
#  '화이트초코 마카다미아 쿠키',
#  '클래식 미니 스콘',
#  '초콜릿 브라우니',
#  '아이스크림 호떡',
#  '꿀호떡',
#  '초콜릿 마카롱',
#  '산딸기 마카롱',
#  '바닐라 마카롱',
#  '이너츠',
#  '베이컨 포테이토 스퀘어 피자',
#  '허니 고르곤졸라 스퀘어 피자',
#  '햄앤치즈샌드위치',
#  '피넛버터앤딸기잼 샌드위치',
#  '팥앤크림 샌드위치',
#  '에그 베이컨 과카몰리 샌드위치',
#  '페퍼로니 피자 샌드위치',
#  '스트로베리 치즈 마카롱',
#  '얼그레이 쇼콜라 마카롱',
#  '쿠키 앤 크림 마카롱',
#  '초코 티라미수',
#  '수플레 치즈 케이크',
#  '데블스 초코 케이크',
#  '떠먹는 티라미수',
#  '더블 치즈 케이크',
#  '밀크레이프 케이크',
#  '마스카포네 티라미수',
#  '레몬 마스카포네',
#  '블루베리 크림치즈',
#  '핫치킨 브리또',
#  '소고기 브리또',
# ...

# %%
driver.get("https://www.ediya.com/contents/drink.html?chked_val=12,13,14,15,16,71,83,&skeyword=#c")

# %%
details = driver.find_elements_by_css_selector('div.detail_con > p')
drink_detail = list(map(lambda x : x.text, details))
drink_detail
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/2452245270.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   details = driver.find_elements_by_css_selector('div.detail_con > p')
# ['',
#  '',
#  '',
#  '',
#  '',
#  '이디야의 노하우가 집약된 골드 블렌드 커피믹스를 엑스트라 사이즈로 즐길 수 있는 음료',
#  '이디야의 노하우가 집약된 골드 블렌드 커피믹스에 쫀득한 버블을 더해 엑스트라 사이즈로 즐길 수 있는 음료',
#  '아삭한 얼음과 요거트가 어우러진 베이스에 아이스크림, 망고패션 베이스, 그래놀라를 올린 빙수',
#  '아삭한 얼음과 요거트가 어우러진 베이스에 아이스크림, 딸기피치 베이스, 그래놀라를 올린 빙수',
#  '재활용 최우수 등급으로 분리 배출이 용이하며, 작아진 라벨 사이즈로 플라스틱 사용량을 최소화한 친환경 생수 *에코탭을 통해 라벨을 쉽게 분리할 수 있습니다.',
#  '생과일 그대로 넣어 갈아 만들어 새콤달콤하고 시원한 토마토주스',
#  '생과일 그대로 넣어 갈아 만들어 새콤달콤하고 시원한 토마토주스',
#  '생과일 그대로 넣어 갈아 만들어 청량하고 시원한 수박주스',
#  '생과일 그대로 넣어 갈아 만들어 청량하고 시원한 수박주스',
#  '부드러운 크림과 에스프레소, 너티 플레이버가 어우러져 만들어진 완벽한 한 잔의 라떼',
#  '토피넛 파우더와 마카다미아향이 어우러져 고소하고 달콤한 음료와 아몬드 브리틀의 바삭한 식감을 즐길 수 있는 음료',
#  '토피넛 파우더와 마카다미아향이 어우러져 고소하고 달콤한 음료와 아몬드 브리틀의 바삭한 식감을 즐길 수 있는 음료',
# ...

# %%
details = driver.find_elements_by_css_selector('div.detail_con > p')
cook_detail = list(map(lambda x : x.text, details))
cook_detail
# Out:
# C:\Users\2020M~1\AppData\Local\Temp/ipykernel_7916/115902558.py:1: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   details = driver.find_elements_by_css_selector('div.detail_con > p')
# ['',
#  '푹신한 도우 위에 짭짜름한 베이컨과 파인애플, 모짜렐라, 체다치즈가 어우러진 간편한끼 스퀘어 피자',
#  '푹신한 도우 위에 맛있게 매운 불닭과 큐브 고구마, 모짜렐라, 체다치즈가 어우러진 간편한끼 스퀘어 피자',
#  '고함량 단백질(13g)과 함께 달콤한 초콜릿 코팅과 쿠키분태, 오곡초코볼, 크리스피볼, 시리얼 등 재미있는 식감을 느낄 수 있는 달콤바삭한 초코바',
#  '비타민C 일일권장량(100mg)과 식이섬유(3g)가 들어있고 동결건조과일 3종의 달콤함과 그릭요거트의 상큼함이 있는 새콤고소한 스낵바',
#  '바삭한 프레첼의 식감에 달콤한 초콜릿 코팅과 짭짤한 소금의 조화로 단짠단짠의 매력을 느낄 수 있는 스낵',
#  '아몬드, 호박씨, 해바라기씨와 벌꿀이 함께 버무려져 고소하고 달콤한 오란다 제품',
#  '시나몬슈가로 마무리한 바삭한 식감을 가진 츄로스. 커피와 함께 할 경우 더욱 풍부한 맛을 느낄 수 있는 베이커리',
#  '이디야 베이커리와 잘 어울리는 진한 초코소스',
#  '향긋한 겨울 생딸기를 듬뿍 올리고 달콤한 연유와 딸기시럽으로 마무리한 허니브레드',
#  '향긋한 겨울 생딸기를 듬뿍 올리고 아이스볼과 플로팅크림으로 풍미를 증가 시킨 벨지움 와플',
#  '버터의 풍미가 가득 느껴지는 크로플 두장에 라운드볼, 휘핑, 그리고 향긋한 겨울 생딸기로 조화를 더한 딸기시즌 한정 디저트',
# ...

# %%
frame = pd.read_csv('corpus_frame.csv', encoding='euc-kr')
menu_df = pd.read_csv('이디야메뉴.csv', encoding='euc-kr')
corpus = []
for idx, i in enumerate(frame['메뉴주문 틀']):
    for item in menu_df['메뉴목록']:
        corpus.append(item + ' ' + i)
corpus2 = pd.DataFrame(corpus)

# %%
corpus2.to_csv('corpus.csv', encoding='euc-kr')
